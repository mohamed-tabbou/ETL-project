# %%
import os
import requests
import json
import pandas as pd
from datetime import datetime
from dotenv import load_dotenv
import mysql.connector
from mysql.connector import Error
import pyodbc

# %%
# Load environment variables from .env file saved in my disktop
load_dotenv('keys.env')

# Load API key to make API requests
RAPIDAPI_KEY = os.getenv('RAPIDAPI_KEY')

# Set up API request headers to authenticate requests
headers = {
    'X-RapidAPI-Key': RAPIDAPI_KEY,
    'X-RapidAPI-Host': 'api-football-v1.p.rapidapi.com'
}
# Set up API URL and parameters
url = "https://api-football-v1.p.rapidapi.com/v3/players/topscorers"
#select the spanish ligue (la liga) 24/25 season
params = {"league":"140","season":"2024"}

# %%
def check_rate_limits():
    """
    Fetch and display the API rate limits from the API-Football service.
    This helps monitor the number of requests available before hitting the limit(100 calls per day).
    """

    if not RAPIDAPI_KEY:
        print("Error: API key not found. Please check your keys.env file.")
        return  
    # Define the API endpoint for fetching top scorers (used here to check rate limits)
    url = "https://api-football-v1.p.rapidapi.com/v3/players/topscorers"
    # Set up the request headers, including the API key
    headers = {
        'X-RapidAPI-Key': RAPIDAPI_KEY,  
        'X-RapidAPI-Host': 'api-football-v1.p.rapidapi.com'  
    }
    try:
        # Send a GET request to the API
        response = requests.get(url, headers=headers)
        # Raise an exception if the response status code indicates an error (e.g., 401, 403, 429)
        response.raise_for_status()
        # Extract rate limit headers from the response
        rate_limits = {
            'daily_limit': response.headers.get('x-ratelimit-requests-limit'),  # Total requests allowed per day
            'daily_remaining': response.headers.get('x-ratelimit-requests-remaining'),  # Requests left for today
            'minute_limit': response.headers.get('x-ratelimit-limit'),  # Requests allowed per minute
            'minute_remaining': response.headers.get('x-ratelimit-remaining')  # Requests left in the current minute
        }
        # Print the extracted rate limits
        print(rate_limits)
    except requests.exceptions.RequestException as e:
        # Handle any request-related errors (e.g., network failure, API errors)
        print("Request failed:", e)
check_rate_limits()
# Out:
# {'daily_limit': '100', 'daily_remaining': '99', 'minute_limit': None, 'minute_remaining': None}

# %%
#extract the data from The API and handle the errors
def get_top_scorers(url, headers, params):
    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.HTTPError as http_error_message:
        print (f"❌ [HTTP ERROR]: {http_error_message}")

    except requests.exceptions.ConnectionError as connection_error_message:
        print (f"❌ [CONNECTION ERROR]: {connection_error_message}")
    except requests.exceptions.Timeout as timeout_error_message:
        print (f"❌ [TIMEOUT ERROR]: {timeout_error_message}")
    except requests.exceptions.RequestException as other_error_message:
        print (f"❌ [UNKNOWN ERROR]: {other_error_message}")
get_top_scorers(url, headers, params)
# Out:
# {'get': 'players/topscorers',
#  'parameters': {'league': '140', 'season': '2024'},
#  'errors': [],
#  'results': 20,
#  'paging': {'current': 1, 'total': 1},
#  'response': [{'player': {'id': 521,
#     'name': 'R. Lewandowski',
#     'firstname': 'Robert',
#     'lastname': 'Lewandowski',
#     'age': 37,
#     'birth': {'date': '1988-08-21', 'place': 'Warszawa', 'country': 'Poland'},
#     'nationality': 'Poland',
#     'height': '185 cm',
#     'weight': '81 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/521.png'},
#    'statistics': [{'team': {'id': 529,
#       'name': 'Barcelona',
#       'logo': 'https://media.api-sports.io/football/teams/529.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 26,
#       'lineups': 25,
#       'minutes': 2106,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.330769',
#       'captain': False},
#      'substitutes': {'in': 1, 'out': 12, 'bench': 2},
#      'shots': {'total': 72, 'on': 40},
#      'goals': {'total': 22, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 417, 'key': 18, 'accuracy': None},
#      'tackles': {'total': 7, 'blocks': 2, 'interceptions': 3},
#      'duels': {'total': 191, 'won': 81},
#      'dribbles': {'attempts': 25, 'success': 15, 'past': None},
#      'fouls': {'drawn': 32, 'committed': 25},
#      'cards': {'yellow': 1, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 3,
#       'missed': 1,
#       'saved': None}}]},
#   {'player': {'id': 278,
#     'name': 'Kylian Mbappé',
#     'firstname': 'Kylian',
#     'lastname': 'Mbappé Lottin',
#     'age': 27,
#     'birth': {'date': '1998-12-20', 'place': 'Paris', 'country': 'France'},
#     'nationality': 'France',
#     'height': '178 cm',
#     'weight': '75 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/278.png'},
#    'statistics': [{'team': {'id': 541,
#       'name': 'Real Madrid',
#       'logo': 'https://media.api-sports.io/football/teams/541.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 26,
#       'lineups': 26,
#       'minutes': 2249,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.623076',
#       'captain': False},
#      'substitutes': {'in': 0, 'out': 11, 'bench': 0},
#      'shots': {'total': 85, 'on': 62},
#      'goals': {'total': 20, 'conceded': 0, 'assists': 3, 'saves': None},
#      'passes': {'total': 846, 'key': 39, 'accuracy': None},
#      'tackles': {'total': 9, 'blocks': None, 'interceptions': None},
#      'duels': {'total': 236, 'won': 103},
#      'dribbles': {'attempts': 136, 'success': 64, 'past': None},
#      'fouls': {'drawn': 28, 'committed': 19},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 5,
#       'missed': 1,
#       'saved': None}}]},
#   {'player': {'id': 46746,
#     'name': 'A. Budimir',
#     'firstname': 'Ante',
#     'lastname': 'Budimir',
#     'age': 34,
#     'birth': {'date': '1991-07-22',
#      'place': 'Zenica',
#      'country': 'Bosnia and Herzegovina'},
#     'nationality': 'Croatia',
#     'height': '190 cm',
#     'weight': '75 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/46746.png'},
#    'statistics': [{'team': {'id': 727,
#       'name': 'Osasuna',
#       'logo': 'https://media.api-sports.io/football/teams/727.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 27,
#       'lineups': 24,
#       'minutes': 2085,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.211111',
#       'captain': False},
#      'substitutes': {'in': 3, 'out': 12, 'bench': 3},
#      'shots': {'total': 54, 'on': 24},
#      'goals': {'total': 15, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 305, 'key': 11, 'accuracy': None},
#      'tackles': {'total': 15, 'blocks': 4, 'interceptions': 1},
#      'duels': {'total': 340, 'won': 152},
#      'dribbles': {'attempts': 28, 'success': 10, 'past': None},
#      'fouls': {'drawn': 22, 'committed': 34},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 7,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 1496,
#     'name': 'Raphinha',
#     'firstname': 'Raphael',
#     'lastname': 'Dias Belloli',
#     'age': 29,
#     'birth': {'date': '1996-12-14',
#      'place': 'Porto Alegre',
#      'country': 'Brazil'},
#     'nationality': 'Brazil',
#     'height': '176 cm',
#     'weight': '68 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/1496.png'},
#    'statistics': [{'team': {'id': 529,
#       'name': 'Barcelona',
#       'logo': 'https://media.api-sports.io/football/teams/529.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 27,
#       'lineups': 26,
#       'minutes': 2225,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.829629',
#       'captain': False},
#      'substitutes': {'in': 1, 'out': 8, 'bench': 1},
#      'shots': {'total': 61, 'on': 34},
#      'goals': {'total': 13, 'conceded': 0, 'assists': 8, 'saves': None},
#      'passes': {'total': 953, 'key': 75, 'accuracy': None},
#      'tackles': {'total': 31, 'blocks': 2, 'interceptions': 5},
#      'duels': {'total': 196, 'won': 109},
#      'dribbles': {'attempts': 82, 'success': 44, 'past': None},
#      'fouls': {'drawn': 28, 'committed': 7},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 128398,
#     'name': 'Oihan Sancet',
#     'firstname': 'Oihan',
#     'lastname': 'Sancet Tirapu',
#     'age': 25,
#     'birth': {'date': '2000-04-25', 'place': 'Pamplona', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '188 cm',
#     'weight': '73 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/128398.png'},
#    'statistics': [{'team': {'id': 531,
#       'name': 'Athletic Club',
#       'logo': 'https://media.api-sports.io/football/teams/531.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 21,
#       'lineups': 17,
#       'minutes': 1357,
#       'number': None,
#       'position': 'Midfielder',
#       'rating': '7.142857',
#       'captain': False},
#      'substitutes': {'in': 4, 'out': 13, 'bench': 4},
#      'shots': {'total': 33, 'on': 17},
#      'goals': {'total': 13, 'conceded': 0, 'assists': 1, 'saves': None},
#      'passes': {'total': 455, 'key': 17, 'accuracy': None},
#      'tackles': {'total': 10, 'blocks': None, 'interceptions': 5},
#      'duels': {'total': 139, 'won': 56},
#      'dribbles': {'attempts': 38, 'success': 19, 'past': None},
#      'fouls': {'drawn': 18, 'committed': 12},
#      'cards': {'yellow': 2, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 2,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 18906,
#     'name': 'Ayoze Pérez',
#     'firstname': 'Ayoze',
#     'lastname': 'Pérez Gutiérrez',
#     'age': 32,
#     'birth': {'date': '1993-07-29',
#      'place': 'Santa Cruz de Tenerife',
#      'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '178 cm',
#     'weight': '66 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/18906.png'},
#    'statistics': [{'team': {'id': 533,
#       'name': 'Villarreal',
#       'logo': 'https://media.api-sports.io/football/teams/533.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 20,
#       'lineups': 13,
#       'minutes': 1258,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.105000',
#       'captain': False},
#      'substitutes': {'in': 7, 'out': 7, 'bench': 7},
#      'shots': {'total': 39, 'on': 19},
#      'goals': {'total': 11, 'conceded': 0, 'assists': 0, 'saves': None},
#      'passes': {'total': 237, 'key': 21, 'accuracy': None},
#      'tackles': {'total': 18, 'blocks': None, 'interceptions': 4},
#      'duels': {'total': 160, 'won': 77},
#      'dribbles': {'attempts': 40, 'success': 21, 'past': None},
#      'fouls': {'drawn': 30, 'committed': 15},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 0,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 6009,
#     'name': 'J. Álvarez',
#     'firstname': 'Julián',
#     'lastname': 'Álvarez',
#     'age': 25,
#     'birth': {'date': '2000-01-31', 'place': 'Cachín', 'country': 'Argentina'},
#     'nationality': 'Argentina',
#     'height': '170 cm',
#     'weight': '71 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/6009.png'},
#    'statistics': [{'team': {'id': 530,
#       'name': 'Atletico Madrid',
#       'logo': 'https://media.api-sports.io/football/teams/530.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 28,
#       'lineups': 22,
#       'minutes': 1826,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.082142',
#       'captain': False},
#      'substitutes': {'in': 6, 'out': 15, 'bench': 6},
#      'shots': {'total': 42, 'on': 26},
#      'goals': {'total': 11, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 623, 'key': 25, 'accuracy': None},
#      'tackles': {'total': 20, 'blocks': None, 'interceptions': None},
#      'duels': {'total': 171, 'won': 59},
#      'dribbles': {'attempts': 41, 'success': 24, 'past': None},
#      'fouls': {'drawn': 3, 'committed': 22},
#      'cards': {'yellow': 4, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 8492,
#     'name': 'A. Sørloth',
#     'firstname': 'Alexander',
#     'lastname': 'Sørloth',
#     'age': 30,
#     'birth': {'date': '1995-12-05', 'place': 'Trondheim', 'country': 'Norway'},
#     'nationality': 'Norway',
#     'height': '195 cm',
#     'weight': '90 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/8492.png'},
#    'statistics': [{'team': {'id': 530,
#       'name': 'Atletico Madrid',
#       'logo': 'https://media.api-sports.io/football/teams/530.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 25,
#       'lineups': 9,
#       'minutes': 1024,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '6.944000',
#       'captain': False},
#      'substitutes': {'in': 16, 'out': 7, 'bench': 18},
#      'shots': {'total': 34, 'on': 22},
#      'goals': {'total': 11, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 258, 'key': 9, 'accuracy': None},
#      'tackles': {'total': 6, 'blocks': 1, 'interceptions': 1},
#      'duels': {'total': 191, 'won': 105},
#      'dribbles': {'attempts': 27, 'success': 13, 'past': None},
#      'fouls': {'drawn': 12, 'committed': 18},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 25458,
#     'name': 'D. Lukebakio',
#     'firstname': 'Dodi',
#     'lastname': 'Lukebakio Ngandoli',
#     'age': 28,
#     'birth': {'date': '1997-09-24', 'place': 'Asse', 'country': 'Belgium'},
#     'nationality': 'Belgium',
#     'height': '187 cm',
#     'weight': '77 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/25458.png'},
#    'statistics': [{'team': {'id': 536,
#       'name': 'Sevilla',
#       'logo': 'https://media.api-sports.io/football/teams/536.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 28,
#       'lineups': 27,
#       'minutes': 2351,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.200000',
#       'captain': False},
#      'substitutes': {'in': 1, 'out': 11, 'bench': 1},
#      'shots': {'total': 57, 'on': 32},
#      'goals': {'total': 11, 'conceded': 0, 'assists': 1, 'saves': None},
#      'passes': {'total': 697, 'key': 42, 'accuracy': None},
#      'tackles': {'total': 18, 'blocks': None, 'interceptions': 4},
#      'duels': {'total': 295, 'won': 143},
#      'dribbles': {'attempts': 134, 'success': 72, 'past': None},
#      'fouls': {'drawn': 40, 'committed': 27},
#      'cards': {'yellow': 2, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 47396,
#     'name': 'Kike García',
#     'firstname': 'Enrique',
#     'lastname': 'García Martínez',
#     'age': 36,
#     'birth': {'date': '1989-11-25',
#      'place': 'Motilla del Palancar',
#      'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '186 cm',
#     'weight': '79 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/47396.png'},
#    'statistics': [{'team': {'id': 542,
#       'name': 'Alaves',
#       'logo': 'https://media.api-sports.io/football/teams/542.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 26,
#       'lineups': 20,
#       'minutes': 1782,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.038461',
#       'captain': False},
#      'substitutes': {'in': 6, 'out': 14, 'bench': 7},
#      'shots': {'total': 31, 'on': 18},
#      'goals': {'total': 11, 'conceded': 0, 'assists': 0, 'saves': None},
#      'passes': {'total': 396, 'key': 12, 'accuracy': None},
#      'tackles': {'total': 9, 'blocks': 2, 'interceptions': None},
#      'duels': {'total': 276, 'won': 141},
#      'dribbles': {'attempts': 21, 'success': 10, 'past': None},
#      'fouls': {'drawn': 41, 'committed': 39},
#      'cards': {'yellow': 4, 'yellowred': 1, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 2,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 762,
#     'name': 'Vinícius Júnior',
#     'firstname': 'Vinícius José',
#     'lastname': 'Paixão de Oliveira Júnior',
#     'age': 25,
#     'birth': {'date': '2000-07-12',
#      'place': 'São Gonçalo',
#      'country': 'Brazil'},
#     'nationality': 'Brazil',
#     'height': '176 cm',
#     'weight': '73 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/762.png'},
#    'statistics': [{'team': {'id': 541,
#       'name': 'Real Madrid',
#       'logo': 'https://media.api-sports.io/football/teams/541.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 22,
#       'lineups': 19,
#       'minutes': 1750,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.390909',
#       'captain': False},
#      'substitutes': {'in': 3, 'out': 8, 'bench': 3},
#      'shots': {'total': 47, 'on': 21},
#      'goals': {'total': 10, 'conceded': 0, 'assists': 5, 'saves': None},
#      'passes': {'total': 620, 'key': 43, 'accuracy': None},
#      'tackles': {'total': 17, 'blocks': None, 'interceptions': 2},
#      'duels': {'total': 289, 'won': 135},
#      'dribbles': {'attempts': 135, 'success': 62, 'past': None},
#      'fouls': {'drawn': 55, 'committed': 25},
#      'cards': {'yellow': 7, 'yellowred': 0, 'red': 1},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 2,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 47324,
#     'name': 'Sandro Ramírez',
#     'firstname': 'Sandro',
#     'lastname': 'Ramírez Castillo',
#     'age': 30,
#     'birth': {'date': '1995-07-09',
#      'place': 'Las Palmas de Gran Canaria',
#      'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '175 cm',
#     'weight': '71 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/47324.png'},
#    'statistics': [{'team': {'id': 534,
#       'name': 'Las Palmas',
#       'logo': 'https://media.api-sports.io/football/teams/534.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 23,
#       'lineups': 20,
#       'minutes': 1632,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.004347',
#       'captain': False},
#      'substitutes': {'in': 3, 'out': 15, 'bench': 3},
#      'shots': {'total': 32, 'on': 18},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 3, 'saves': None},
#      'passes': {'total': 416, 'key': 19, 'accuracy': None},
#      'tackles': {'total': 22, 'blocks': None, 'interceptions': 14},
#      'duels': {'total': 162, 'won': 74},
#      'dribbles': {'attempts': 32, 'success': 12, 'past': None},
#      'fouls': {'drawn': 31, 'committed': 21},
#      'cards': {'yellow': 6, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 0,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 56,
#     'name': 'A. Griezmann',
#     'firstname': 'Antoine',
#     'lastname': 'Griezmann',
#     'age': 34,
#     'birth': {'date': '1991-03-21', 'place': 'Mâcon', 'country': 'France'},
#     'nationality': 'France',
#     'height': '176 cm',
#     'weight': '73 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/56.png'},
#    'statistics': [{'team': {'id': 530,
#       'name': 'Atletico Madrid',
#       'logo': 'https://media.api-sports.io/football/teams/530.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 28,
#       'lineups': 24,
#       'minutes': 2030,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.289285',
#       'captain': False},
#      'substitutes': {'in': 4, 'out': 16, 'bench': 4},
#      'shots': {'total': 29, 'on': 14},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 5, 'saves': None},
#      'passes': {'total': 1028, 'key': 42, 'accuracy': None},
#      'tackles': {'total': 28, 'blocks': None, 'interceptions': 6},
#      'duels': {'total': 158, 'won': 78},
#      'dribbles': {'attempts': 24, 'success': 11, 'past': None},
#      'fouls': {'drawn': 22, 'committed': 11},
#      'cards': {'yellow': 2, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 1,
#       'saved': None}}]},
#   {'player': {'id': 343684,
#     'name': 'T. Barry',
#     'firstname': 'Thierno',
#     'lastname': 'Barry',
#     'age': 23,
#     'birth': {'date': '2002-10-21', 'place': 'Lyon', 'country': 'France'},
#     'nationality': 'France',
#     'height': '195 cm',
#     'weight': '82 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/343684.png'},
#    'statistics': [{'team': {'id': 533,
#       'name': 'Villarreal',
#       'logo': 'https://media.api-sports.io/football/teams/533.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 26,
#       'lineups': 17,
#       'minutes': 1618,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '6.930769',
#       'captain': False},
#      'substitutes': {'in': 9, 'out': 7, 'bench': 9},
#      'shots': {'total': 48, 'on': 17},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 3, 'saves': None},
#      'passes': {'total': 232, 'key': 17, 'accuracy': None},
#      'tackles': {'total': 12, 'blocks': 2, 'interceptions': None},
#      'duels': {'total': 233, 'won': 128},
#      'dribbles': {'attempts': 27, 'success': 11, 'past': None},
#      'fouls': {'drawn': 34, 'committed': 30},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 129791,
#     'name': 'Fábio Silva',
#     'firstname': 'Fábio Daniel',
#     'lastname': 'Soares Silva',
#     'age': 23,
#     'birth': {'date': '2002-07-19', 'place': 'Porto', 'country': 'Portugal'},
#     'nationality': 'Portugal',
#     'height': '185 cm',
#     'weight': '75 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/129791.png'},
#    'statistics': [{'team': {'id': 534,
#       'name': 'Las Palmas',
#       'logo': 'https://media.api-sports.io/football/teams/534.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 20,
#       'lineups': 18,
#       'minutes': 1526,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.025000',
#       'captain': False},
#      'substitutes': {'in': 2, 'out': 11, 'bench': 2},
#      'shots': {'total': 38, 'on': 20},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 348, 'key': 12, 'accuracy': None},
#      'tackles': {'total': 10, 'blocks': None, 'interceptions': 3},
#      'duels': {'total': 227, 'won': 105},
#      'dribbles': {'attempts': 38, 'success': 16, 'past': None},
#      'fouls': {'drawn': 35, 'committed': 33},
#      'cards': {'yellow': 7, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 2,
#       'missed': 1,
#       'saved': None}}]},
#   {'player': {'id': 47349,
#     'name': 'Javi Puado',
#     'firstname': 'Javier',
#     'lastname': 'Puado Díaz',
#     'age': 27,
#     'birth': {'date': '1998-05-25', 'place': 'Barcelona', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '177 cm',
#     'weight': '69 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/47349.png'},
#    'statistics': [{'team': {'id': 540,
#       'name': 'Espanyol',
#       'logo': 'https://media.api-sports.io/football/teams/540.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 25,
#       'lineups': 25,
#       'minutes': 2147,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '6.868000',
#       'captain': False},
#      'substitutes': {'in': 0, 'out': 8, 'bench': 0},
#      'shots': {'total': 39, 'on': 14},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 1, 'saves': None},
#      'passes': {'total': 440, 'key': 16, 'accuracy': None},
#      'tackles': {'total': 15, 'blocks': 2, 'interceptions': 4},
#      'duels': {'total': 149, 'won': 60},
#      'dribbles': {'attempts': 43, 'success': 17, 'past': None},
#      'fouls': {'drawn': 21, 'committed': 14},
#      'cards': {'yellow': 4, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 2,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 47258,
#     'name': 'M. Arambarri',
#     'firstname': 'Mauro Wilney',
#     'lastname': 'Arambarri Rosa',
#     'age': 30,
#     'birth': {'date': '1995-09-30', 'place': 'Tropezón', 'country': 'Uruguay'},
#     'nationality': 'Uruguay',
#     'height': '175 cm',
#     'weight': '71 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/47258.png'},
#    'statistics': [{'team': {'id': 546,
#       'name': 'Getafe',
#       'logo': 'https://media.api-sports.io/football/teams/546.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 26,
#       'lineups': 22,
#       'minutes': 1899,
#       'number': None,
#       'position': 'Midfielder',
#       'rating': '6.880769',
#       'captain': False},
#      'substitutes': {'in': 4, 'out': 6, 'bench': 4},
#      'shots': {'total': 28, 'on': 13},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 0, 'saves': None},
#      'passes': {'total': 556, 'key': 10, 'accuracy': None},
#      'tackles': {'total': 30, 'blocks': 5, 'interceptions': 9},
#      'duels': {'total': 243, 'won': 121},
#      'dribbles': {'attempts': 23, 'success': 14, 'past': None},
#      'fouls': {'drawn': 34, 'committed': 31},
#      'cards': {'yellow': 8, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 3,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 47445,
#     'name': 'Iago Aspas',
#     'firstname': 'Iago',
#     'lastname': 'Aspas Juncal',
#     'age': 38,
#     'birth': {'date': '1987-08-01', 'place': 'Moaña', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '176 cm',
#     'weight': '67 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/47445.png'},
#    'statistics': [{'team': {'id': 538,
#       'name': 'Celta Vigo',
#       'logo': 'https://media.api-sports.io/football/teams/538.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 21,
#       'lineups': 15,
#       'minutes': 1397,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.300000',
#       'captain': False},
#      'substitutes': {'in': 6, 'out': 6, 'bench': 8},
#      'shots': {'total': 35, 'on': 19},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 3, 'saves': None},
#      'passes': {'total': 661, 'key': 25, 'accuracy': None},
#      'tackles': {'total': 12, 'blocks': 1, 'interceptions': 6},
#      'duels': {'total': 114, 'won': 60},
#      'dribbles': {'attempts': 17, 'success': 10, 'past': None},
#      'fouls': {'drawn': 31, 'committed': 14},
#      'cards': {'yellow': 3, 'yellowred': 1, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 4,
#       'missed': 1,
#       'saved': None}}]},
#   {'player': {'id': 47264,
#     'name': 'Hugo Duro',
#     'firstname': 'Hugo',
#     'lastname': 'Duro Perales',
#     'age': 26,
#     'birth': {'date': '1999-11-10', 'place': 'Getafe', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '177 cm',
#     'weight': '70 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/47264.png'},
#    'statistics': [{'team': {'id': 532,
#       'name': 'Valencia',
#       'logo': 'https://media.api-sports.io/football/teams/532.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 22,
#       'lineups': 20,
#       'minutes': 1702,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '6.872727',
#       'captain': False},
#      'substitutes': {'in': 2, 'out': 8, 'bench': 3},
#      'shots': {'total': 28, 'on': 12},
#      'goals': {'total': 7, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 329, 'key': 12, 'accuracy': None},
#      'tackles': {'total': 12, 'blocks': 2, 'interceptions': 9},
#      'duels': {'total': 262, 'won': 109},
#      'dribbles': {'attempts': 19, 'success': 7, 'past': None},
#      'fouls': {'drawn': 41, 'committed': 28},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 0,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 931,
#     'name': 'Ferran Torres',
#     'firstname': 'Ferran',
#     'lastname': 'Torres García',
#     'age': 25,
#     'birth': {'date': '2000-02-29', 'place': 'Foios', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '184 cm',
#     'weight': '77 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/931.png'},
#    'statistics': [{'team': {'id': 529,
#       'name': 'Barcelona',
#       'logo': 'https://media.api-sports.io/football/teams/529.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 20,
#       'lineups': 7,
#       'minutes': 706,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.005263',
#       'captain': False},
#      'substitutes': {'in': 13, 'out': 5, 'bench': 14},
#      'shots': {'total': 24, 'on': 16},
#      'goals': {'total': 7, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 219, 'key': 10, 'accuracy': None},
#      'tackles': {'total': 6, 'blocks': 1, 'interceptions': 1},
#      'duels': {'total': 43, 'won': 22},
#      'dribbles': {'attempts': 13, 'success': 9, 'past': None},
#      'fouls': {'drawn': 5, 'committed': 5},
#      'cards': {'yellow': 1, 'yellowred': 0, 'red': 1},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 0,
#       'missed': 0,
#       'saved': None}}]}]}

# %%
#This step represents the transformation phase of the ETL pipeline (T).
def process_top_scorers(data):
    """
    Parse the JSON data required for the top scorers 
    """
    top_scorers = []
    for scorer_data in data['response']:#The data we need is found in the response key. Response is an array of objects with all the detailed information we need about each top goal scorer.
        statistics = scorer_data['statistics'][0]

        # Set up constants for processing data 
        player = scorer_data['player']
        player_name = player['name']
        club_name = statistics['team']['name']
        club_logo = statistics['team']['logo']
        total_goals = int(statistics['goals']['total'])
        penalty_goals = int(statistics['penalty']['scored'])
        total_shots = int(statistics['shots']['total'])
        assists = int(statistics['goals']['assists']) if statistics['goals']['assists'] else 0
        matches_played = int(statistics['games']['appearences'])
        minutes_played = int(statistics['games']['minutes'])
        dob = datetime.strptime(player['birth']['date'], '%Y-%m-%d')
        age = (datetime.now() - dob).days // 365

        # Append data 
        top_scorers.append({
            'player': player_name,
            'club': club_name,
            'total_goals': total_goals,
            'penalty_goals': penalty_goals,
            'assists': assists,
            'matches': matches_played,
            'mins': minutes_played,
            'age': age,
            'total_shots': total_shots,
            'club_logo':club_logo
        })
    return top_scorers
process_top_scorers(get_top_scorers(url, headers, params))
# Out:
# [{'player': 'R. Lewandowski',
#   'club': 'Barcelona',
#   'total_goals': 22,
#   'penalty_goals': 3,
#   'assists': 2,
#   'matches': 26,
#   'mins': 2106,
#   'age': 36,
#   'total_shots': 72,
#   'club_logo': 'https://media.api-sports.io/football/teams/529.png'},
#  {'player': 'Kylian Mbappé',
#   'club': 'Real Madrid',
#   'total_goals': 20,
#   'penalty_goals': 5,
#   'assists': 3,
#   'matches': 26,
#   'mins': 2249,
#   'age': 26,
#   'total_shots': 85,
#   'club_logo': 'https://media.api-sports.io/football/teams/541.png'},
#  {'player': 'A. Budimir',
#   'club': 'Osasuna',
#   'total_goals': 15,
#   'penalty_goals': 7,
#   'assists': 2,
#   'matches': 27,
#   'mins': 2085,
#   'age': 33,
#   'total_shots': 54,
#   'club_logo': 'https://media.api-sports.io/football/teams/727.png'},
#  {'player': 'Raphinha',
#   'club': 'Barcelona',
#   'total_goals': 13,
#   'penalty_goals': 1,
#   'assists': 8,
#   'matches': 27,
#   'mins': 2225,
#   'age': 28,
#   'total_shots': 61,
#   'club_logo': 'https://media.api-sports.io/football/teams/529.png'},
#  {'player': 'Oihan Sancet',
#   'club': 'Athletic Club',
#   'total_goals': 13,
#   'penalty_goals': 2,
#   'assists': 1,
#   'matches': 21,
#   'mins': 1357,
#   'age': 24,
#   'total_shots': 33,
#   'club_logo': 'https://media.api-sports.io/football/teams/531.png'},
#  {'player': 'Ayoze Pérez',
#   'club': 'Villarreal',
#   'total_goals': 11,
#   'penalty_goals': 0,
#   'assists': 0,
#   'matches': 20,
#   'mins': 1258,
#   'age': 31,
#   'total_shots': 39,
#   'club_logo': 'https://media.api-sports.io/football/teams/533.png'},
#  {'player': 'J. Álvarez',
#   'club': 'Atletico Madrid',
#   'total_goals': 11,
#   'penalty_goals': 1,
#   'assists': 2,
#   'matches': 28,
#   'mins': 1826,
#   'age': 25,
#   'total_shots': 42,
#   'club_logo': 'https://media.api-sports.io/football/teams/530.png'},
#  {'player': 'A. Sørloth',
#   'club': 'Atletico Madrid',
#   'total_goals': 11,
#   'penalty_goals': 1,
#   'assists': 2,
#   'matches': 25,
#   'mins': 1024,
#   'age': 29,
#   'total_shots': 34,
#   'club_logo': 'https://media.api-sports.io/football/teams/530.png'},
#  {'player': 'D. Lukebakio',
#   'club': 'Sevilla',
#   'total_goals': 11,
#   'penalty_goals': 1,
#   'assists': 1,
#   'matches': 28,
#   'mins': 2351,
#   'age': 27,
#   'total_shots': 57,
#   'club_logo': 'https://media.api-sports.io/football/teams/536.png'},
#  {'player': 'Kike García',
#   'club': 'Alaves',
#   'total_goals': 11,
#   'penalty_goals': 2,
#   'assists': 0,
#   'matches': 26,
#   'mins': 1782,
#   'age': 35,
#   'total_shots': 31,
#   'club_logo': 'https://media.api-sports.io/football/teams/542.png'},
#  {'player': 'Vinícius Júnior',
#   'club': 'Real Madrid',
#   'total_goals': 10,
#   'penalty_goals': 2,
#   'assists': 5,
#   'matches': 22,
#   'mins': 1750,
#   'age': 24,
#   'total_shots': 47,
#   'club_logo': 'https://media.api-sports.io/football/teams/541.png'},
#  {'player': 'Sandro Ramírez',
#   'club': 'Las Palmas',
#   'total_goals': 8,
#   'penalty_goals': 0,
#   'assists': 3,
#   'matches': 23,
#   'mins': 1632,
#   'age': 29,
#   'total_shots': 32,
#   'club_logo': 'https://media.api-sports.io/football/teams/534.png'},
#  {'player': 'A. Griezmann',
#   'club': 'Atletico Madrid',
#   'total_goals': 8,
#   'penalty_goals': 1,
#   'assists': 5,
#   'matches': 28,
#   'mins': 2030,
#   'age': 34,
#   'total_shots': 29,
#   'club_logo': 'https://media.api-sports.io/football/teams/530.png'},
#  {'player': 'T. Barry',
#   'club': 'Villarreal',
#   'total_goals': 8,
#   'penalty_goals': 1,
#   'assists': 3,
#   'matches': 26,
#   'mins': 1618,
#   'age': 22,
#   'total_shots': 48,
#   'club_logo': 'https://media.api-sports.io/football/teams/533.png'},
#  {'player': 'Fábio Silva',
#   'club': 'Las Palmas',
#   'total_goals': 8,
#   'penalty_goals': 2,
#   'assists': 2,
#   'matches': 20,
#   'mins': 1526,
#   'age': 22,
#   'total_shots': 38,
#   'club_logo': 'https://media.api-sports.io/football/teams/534.png'},
#  {'player': 'Javi Puado',
#   'club': 'Espanyol',
#   'total_goals': 8,
#   'penalty_goals': 2,
#   'assists': 1,
#   'matches': 25,
#   'mins': 2147,
#   'age': 26,
#   'total_shots': 39,
#   'club_logo': 'https://media.api-sports.io/football/teams/540.png'},
#  {'player': 'M. Arambarri',
#   'club': 'Getafe',
#   'total_goals': 8,
#   'penalty_goals': 3,
#   'assists': 0,
#   'matches': 26,
#   'mins': 1899,
#   'age': 29,
#   'total_shots': 28,
#   'club_logo': 'https://media.api-sports.io/football/teams/546.png'},
#  {'player': 'Iago Aspas',
#   'club': 'Celta Vigo',
#   'total_goals': 8,
#   'penalty_goals': 4,
#   'assists': 3,
#   'matches': 21,
#   'mins': 1397,
#   'age': 37,
#   'total_shots': 35,
#   'club_logo': 'https://media.api-sports.io/football/teams/538.png'},
#  {'player': 'Hugo Duro',
#   'club': 'Valencia',
#   'total_goals': 7,
#   'penalty_goals': 0,
#   'assists': 2,
#   'matches': 22,
#   'mins': 1702,
#   'age': 25,
#   'total_shots': 28,
#   'club_logo': 'https://media.api-sports.io/football/teams/532.png'},
#  {'player': 'Ferran Torres',
#   'club': 'Barcelona',
#   'total_goals': 7,
#   'penalty_goals': 0,
#   'assists': 2,
#   'matches': 20,
#   'mins': 706,
#   'age': 25,
#   'total_shots': 24,
#   'club_logo': 'https://media.api-sports.io/football/teams/529.png'}]

# %%
def create_dataframe(top_scorers):
    """
    Convert list of dictionaries into a Pandas dataframe and process it
    """

    df = pd.DataFrame(top_scorers)

    # Sort dataframe first by 'total_goals' in descending order, then by 'assists' in descending order
    df.sort_values(by=['total_goals', 'assists'], ascending=[False, False], inplace=True)

    # Reset index after sorting to reflect new order
    df.reset_index(drop=True, inplace=True)

    # Recalculate ranks based on the sorted order of 'total_goals' using dense method 
    df['position'] = df['total_goals'].rank(method='dense', ascending=False).astype(int)

    # Specify the columns to include in the final dataframe in the desired order
    df = df[['position', 'player', 'club', 'total_goals', 'penalty_goals', 'assists', 'matches', 'mins', 'age','total_shots','club_logo']]

    return df
create_dataframe(process_top_scorers(get_top_scorers(url, headers, params)))
# Out:
#     position           player             club  total_goals  penalty_goals  \
# 0          1   R. Lewandowski        Barcelona           22              3
# 1          2    Kylian Mbappé      Real Madrid           20              5
# 2          3       A. Budimir          Osasuna           15              7
# 3          4         Raphinha        Barcelona           13              1
# 4          4     Oihan Sancet    Athletic Club           13              2
# 5          5       J. Álvarez  Atletico Madrid           11              1
# 6          5       A. Sørloth  Atletico Madrid           11              1
# 7          5     D. Lukebakio          Sevilla           11              1
# 8          5      Ayoze Pérez       Villarreal           11              0
# 9          5      Kike García           Alaves           11              2
# 10         6  Vinícius Júnior      Real Madrid           10              2
# 11         7     A. Griezmann  Atletico Madrid            8              1
# 12         7   Sandro Ramírez       Las Palmas            8              0
# 13         7         T. Barry       Villarreal            8              1
# 14         7       Iago Aspas       Celta Vigo            8              4
# 15         7      Fábio Silva       Las Palmas            8              2
# 16         7       Javi Puado         Espanyol            8              2
# 17         7     M. Arambarri           Getafe            8              3
# 18         8        Hugo Duro         Valencia            7              0
# 19         8    Ferran Torres        Barcelona            7              0
#
#     assists  matches  mins  age  total_shots  \
# 0         2       26  2106   36           72
# 1         3       26  2249   26           85
# 2         2       27  2085   33           54
# 3         8       27  2225   28           61
# 4         1       21  1357   24           33
# 5         2       28  1826   25           42
# 6         2       25  1024   29           34
# 7         1       28  2351   27           57
# 8         0       20  1258   31           39
# 9         0       26  1782   35           31
# 10        5       22  1750   24           47
# 11        5       28  2030   34           29
# 12        3       23  1632   29           32
# 13        3       26  1618   22           48
# 14        3       21  1397   37           35
# 15        2       20  1526   22           38
# 16        1       25  2147   26           39
# 17        0       26  1899   29           28
# 18        2       22  1702   25           28
# 19        2       20   706   25           24
#
#                                             club_logo
# 0   https://media.api-sports.io/football/teams/529...
# 1   https://media.api-sports.io/football/teams/541...
# 2   https://media.api-sports.io/football/teams/727...
# 3   https://media.api-sports.io/football/teams/529...
# 4   https://media.api-sports.io/football/teams/531...
# 5   https://media.api-sports.io/football/teams/530...
# 6   https://media.api-sports.io/football/teams/530...
# 7   https://media.api-sports.io/football/teams/536...
# 8   https://media.api-sports.io/football/teams/533...
# 9   https://media.api-sports.io/football/teams/542...
# 10  https://media.api-sports.io/football/teams/541...
# 11  https://media.api-sports.io/football/teams/530...
# 12  https://media.api-sports.io/football/teams/534...
# 13  https://media.api-sports.io/football/teams/533...
# 14  https://media.api-sports.io/football/teams/538...
# 15  https://media.api-sports.io/football/teams/534...
# 16  https://media.api-sports.io/football/teams/540...
# 17  https://media.api-sports.io/football/teams/546...
# 18  https://media.api-sports.io/football/teams/532...
# 19  https://media.api-sports.io/football/teams/529...

# %%
load_dotenv('keys.env')
# Load MySQL database credentials saved in my file.env named keys
SERVER = os.getenv('SERVER')
MY_DATABASE = os.getenv('MY_DATABASE')

# %%
# Establish a connection to the MySQL database
def create_db_connection(server_name, db_name):
    """
    Establish a connection to the SQL Server database using Windows Authentication.
    """
    db_connection = None
    try:
        db_connection = pyodbc.connect(
            f'DRIVER={{SQL Server}};'
            f'SERVER={server_name};'
            f'DATABASE={db_name};'
            f'Trusted_Connection=yes;'
        )
        print("✅ SQL Server Database connection successful!")

    except pyodbc.Error as e:
        print(f"❌ [DATABASE CONNECTION ERROR]: {e}")

    return db_connection

create_db_connection(SERVER, MY_DATABASE)
# Out:
# ✅ SQL Server Database connection successful!

# %%
def create_table(db_connection):
    """
    Create a table if it does not exist in the SQL Server database
    """
    CREATE_TABLE_SQL_QUERY = """
    IF NOT EXISTS (SELECT * FROM sysobjects WHERE name='top_scorers' AND xtype='U')
    CREATE TABLE top_scorers (
        position INT,
        player VARCHAR(255),
        club VARCHAR(255),
        total_goals INT,
        penalty_goals INT,
        assists INT,
        matches INT,
        mins INT,
        age INT,
        total_shots INT, 
        club_logo VARCHAR(255),
        PRIMARY KEY (player, club)
    );
    """
    
    try:
        cursor = db_connection.cursor()
        cursor.execute(CREATE_TABLE_SQL_QUERY)
        db_connection.commit()
        print("✅ Table 'top_scorers' created successfully!")

    except pyodbc.Error as e:
        print(f"❌ [CREATING TABLE ERROR]: {e}")
create_table(create_db_connection(SERVER, MY_DATABASE))
# Out:
# ✅ SQL Server Database connection successful!
# ✅ Table 'top_scorers' created successfully!

# %%
# Insert data into the table
def insert_into_table(db_connection, df):
    """
    Insert or update the top scorers data in the database from the dataframe
    """
    cursor = db_connection.cursor()

    INSERT_DATA_SQL_QUERY = """
    MERGE INTO top_scorers AS target
    USING (VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)) AS source (position, player, club, total_goals, penalty_goals, assists, matches, mins, age, total_shots, club_logo)
    ON target.player = source.player AND target.club = source.club
    WHEN MATCHED THEN
        UPDATE SET
            target.total_goals = source.total_goals,
            target.penalty_goals = source.penalty_goals,
            target.assists = source.assists,
            target.matches = source.matches,
            target.mins = source.mins,
            target.age = source.age,
            target.total_shots = source.total_shots,  -- Update this line if the column name is different
            target.club_logo = source.club_logo
    WHEN NOT MATCHED THEN
        INSERT (position, player, club, total_goals, penalty_goals, assists, matches, mins, age, total_shots, club_logo)  -- Update this line if the column name is different
        VALUES (source.position, source.player, source.club, source.total_goals, source.penalty_goals, source.assists, source.matches, source.mins, source.age, source.total_shots, source.club_logo);
    """

    # Create a list of tuples from the dataframe values
    data_values_as_tuples = [tuple(x) for x in df.to_numpy()]

    # Execute the query
    cursor.executemany(INSERT_DATA_SQL_QUERY, data_values_as_tuples)
    db_connection.commit()
    print("Data inserted or updated successfully ✅")
insert_into_table(create_db_connection(SERVER, MY_DATABASE), create_dataframe(process_top_scorers(get_top_scorers(url, headers, params))))
# Out:
# ✅ SQL Server Database connection successful!
# Data inserted or updated successfully ✅

# %%
def run_data_pipeline():
    """
    Execute the ETL pipeline 
    """
    check_rate_limits()

    data = get_top_scorers(url, headers, params)

    if data and 'response' in data and data['response']:
        top_scorers = process_top_scorers(data)
        df = create_dataframe(top_scorers)
        print(df.to_string(index=False)) 

    else:
        print("No data available or an error occurred ❌")

    db_connection = create_db_connection(SERVER, MY_DATABASE)


    # If connection is successful, proceed with creating table and inserting data
    if db_connection is not None:
        create_table(db_connection)  
        df = create_dataframe(top_scorers) 
        insert_into_table(db_connection, df)  

if __name__ == "__main__":
    run_data_pipeline()
# Out:
# {'daily_limit': '100', 'daily_remaining': '94', 'minute_limit': None, 'minute_remaining': None}
#  position          player            club  total_goals  penalty_goals  assists  matches  mins  age  total_shots                                          club_logo
#         1  R. Lewandowski       Barcelona           22              3        2       26  2106   36           72 https://media.api-sports.io/football/teams/529.png
#         2   Kylian Mbappé     Real Madrid           20              5        3       26  2249   26           85 https://media.api-sports.io/football/teams/541.png
#         3      A. Budimir         Osasuna           15              7        2       27  2085   33           54 https://media.api-sports.io/football/teams/727.png
#         4        Raphinha       Barcelona           13              1        8       27  2225   28           61 https://media.api-sports.io/football/teams/529.png
#         4    Oihan Sancet   Athletic Club           13              2        1       21  1357   24           33 https://media.api-sports.io/football/teams/531.png
#         5      J. Álvarez Atletico Madrid           11              1        2       28  1826   25           42 https://media.api-sports.io/football/teams/530.png
#         5      A. Sørloth Atletico Madrid           11              1        2       25  1024   29           34 https://media.api-sports.io/football/teams/530.png
#         5    D. Lukebakio         Sevilla           11              1        1       28  2351   27           57 https://media.api-sports.io/football/teams/536.png
#         5     Ayoze Pérez      Villarreal           11              0        0       20  1258   31           39 https://media.api-sports.io/football/teams/533.png
#         5     Kike García          Alaves           11              2        0       26  1782   35           31 https://media.api-sports.io/football/teams/542.png
#         6 Vinícius Júnior     Real Madrid           10              2        5       22  1750   24           47 https://media.api-sports.io/football/teams/541.png
#         7    A. Griezmann Atletico Madrid            8              1        5       28  2030   34           29 https://media.api-sports.io/football/teams/530.png
#         7  Sandro Ramírez      Las Palmas            8              0        3       23  1632   29           32 https://media.api-sports.io/football/teams/534.png
#         7        T. Barry      Villarreal            8              1        3       26  1618   22           48 https://media.api-sports.io/football/teams/533.png
#         7      Iago Aspas      Celta Vigo            8              4        3       21  1397   37           35 https://media.api-sports.io/football/teams/538.png
#         7     Fábio Silva      Las Palmas            8              2        2       20  1526   22           38 https://media.api-sports.io/football/teams/534.png
#         7      Javi Puado        Espanyol            8              2        1       25  2147   26           39 https://media.api-sports.io/football/teams/540.png
#         7    M. Arambarri          Getafe            8              3        0       26  1899   29           28 https://media.api-sports.io/football/teams/546.png
#         8       Hugo Duro        Valencia            7              0        2       22  1702   25           28 https://media.api-sports.io/football/teams/532.png
#         8   Ferran Torres       Barcelona            7              0        2       20   706   25           24 https://media.api-sports.io/football/teams/529.png
# ✅ SQL Server Database connection successful!
# ✅ Table 'top_scorers' created successfully!
# Data inserted or updated successfully ✅
