# %%
import os
import requests
import json
import pandas as pd
from datetime import datetime
from dotenv import load_dotenv
import mysql.connector
from mysql.connector import Error
import pyodbc

# %%
def check_rate_limits():
    """
    Fetch and display the API rate limits from the API-Football service.
    This helps monitor the number of requests available before hitting the limit(100 calls per day).
    """

    # Load environment variables from the 'keys.env' file saved in my directory
    load_dotenv('keys.env')
    # Retrieve the API key from environment variables
    RAPIDAPI_KEY = os.getenv('RAPIDAPI_KEY')
    # Check if the API key is loaded correctly
    if not RAPIDAPI_KEY:
        print("Error: API key not found. Please check your keys.env file.")
        return  
    # Define the API endpoint for fetching top scorers (used here to check rate limits)
    url = "https://api-football-v1.p.rapidapi.com/v3/players/topscorers"
    # Set up the request headers, including the API key
    headers = {
        'X-RapidAPI-Key': RAPIDAPI_KEY,  
        'X-RapidAPI-Host': 'api-football-v1.p.rapidapi.com'  
    }
    try:
        # Send a GET request to the API
        response = requests.get(url, headers=headers)
        # Raise an exception if the response status code indicates an error (e.g., 401, 403, 429)
        response.raise_for_status()
        # Extract rate limit headers from the response
        rate_limits = {
            'daily_limit': response.headers.get('x-ratelimit-requests-limit'),  # Total requests allowed per day
            'daily_remaining': response.headers.get('x-ratelimit-requests-remaining'),  # Requests left for today
            'minute_limit': response.headers.get('x-ratelimit-limit'),  # Requests allowed per minute
            'minute_remaining': response.headers.get('x-ratelimit-remaining')  # Requests left in the current minute
        }
        # Print the extracted rate limits
        print(rate_limits)
    except requests.exceptions.RequestException as e:
        # Handle any request-related errors (e.g., network failure, API errors)
        print("Request failed:", e)
check_rate_limits()
# Out:
# {'daily_limit': '100', 'daily_remaining': '76', 'minute_limit': None, 'minute_remaining': None}

# %%
#exemple of fetching first top scorer of 24/25 (til now ) the french league 1  from the API 
# Load environment variables
load_dotenv('keys.env')

# Read API key
RAPIDAPI_KEY = os.getenv('RAPIDAPI_KEY')

# Check if the API key is loaded properly
if not RAPIDAPI_KEY:
    print("Error: API key not found. Please check your keys.env file.")
else:
    print("API Key Loaded Successfully")

# Set up API URL and parameters
url = "https://api-football-v1.p.rapidapi.com/v3/players/topscorers"
headers = {
    'X-RapidAPI-Key': RAPIDAPI_KEY,
    'X-RapidAPI-Host': 'api-football-v1.p.rapidapi.com'
}
params = {"league": "140", "season": "2024"}

# Make the API request
response = requests.get(url, headers=headers, params=params)

# Check status code before parsing JSON
print("Status Code:", response.status_code)

# If successful, print JSON response
if response.status_code == 200:
    data = response.json()
    # Extract information for the first player
    first_player_info = data['response'][0]
    # Display the first player's information in JSON format
    print(json.dumps(first_player_info, indent=4))
else:
    print("Error:", response.text)  # Print raw response for debugging
# Out:
# API Key Loaded Successfully
# Status Code: 200
# {
#     "player": {
#         "id": 521,
#         "name": "R. Lewandowski",
#         "firstname": "Robert",
#         "lastname": "Lewandowski",
#         "age": 37,
#         "birth": {
#             "date": "1988-08-21",
#             "place": "Warszawa",
#             "country": "Poland"
#         },
#         "nationality": "Poland",
#         "height": "185 cm",
#         "weight": "81 kg",
#         "injured": false,
#         "photo": "https://media.api-sports.io/football/players/521.png"
#     },
#     "statistics": [
#         {
#             "team": {
#                 "id": 529,
#                 "name": "Barcelona",
#                 "logo": "https://media.api-sports.io/football/teams/529.png"
#             },
#             "league": {
#                 "id": 140,
#                 "name": "La Liga",
#                 "country": "Spain",
#                 "logo": "https://media.api-sports.io/football/leagues/140.png",
#                 "flag": "https://media.api-sports.io/flags/es.svg",
#                 "season": 2024
#             },
#             "games": {
#                 "appearences": 25,
#                 "lineups": 24,
#                 "minutes": 2016,
#                 "number": null,
#                 "position": "Attacker",
#                 "rating": "7.348000",
#                 "captain": false
#             },
#             "substitutes": {
#                 "in": 1,
#                 "out": 12,
#                 "bench": 2
#             },
#             "shots": {
#                 "total": 67,
#                 "on": 38
#             },
#             "goals": {
#                 "total": 21,
#                 "conceded": 0,
#                 "assists": 2,
#                 "saves": null
#             },
#             "passes": {
#                 "total": 404,
#                 "key": 18,
#                 "accuracy": null
#             },
#             "tackles": {
#                 "total": 7,
#                 "blocks": 2,
#                 "interceptions": 3
#             },
#             "duels": {
#                 "total": 177,
#                 "won": 76
#             },
#             "dribbles": {
#                 "attempts": 24,
#                 "success": 15,
#                 "past": null
#             },
#             "fouls": {
#                 "drawn": 29,
#                 "committed": 22
#             },
#             "cards": {
#                 "yellow": 1,
#                 "yellowred": 0,
#                 "red": 0
#             },
#             "penalty": {
#                 "won": null,
#                 "commited": null,
#                 "scored": 3,
#                 "missed": 1,
#                 "saved": null
#             }
#         }
#     ]
# }

# %%
# Load environment variables from .env file
load_dotenv('keys.env')

# Load API key to make API requests
RAPIDAPI_KEY = os.getenv('RAPIDAPI_KEY')

# Set up API request headers to authenticate requests
headers = {
    'X-RapidAPI-Key': RAPIDAPI_KEY,
    'X-RapidAPI-Host': 'api-football-v1.p.rapidapi.com'
}
# Set up API URL and parameters
url = "https://api-football-v1.p.rapidapi.com/v3/players/topscorers"
#select the french League 1 and 24/25 season
params = {"league":"140","season":"2024"}

# %%
#extract the data from The API and handle the errors
def get_top_scorers(url, headers, params):
    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.HTTPError as http_error_message:
        print (f"❌ [HTTP ERROR]: {http_error_message}")

    except requests.exceptions.ConnectionError as connection_error_message:
        print (f"❌ [CONNECTION ERROR]: {connection_error_message}")
    except requests.exceptions.Timeout as timeout_error_message:
        print (f"❌ [TIMEOUT ERROR]: {timeout_error_message}")
    except requests.exceptions.RequestException as other_error_message:
        print (f"❌ [UNKNOWN ERROR]: {other_error_message}")
get_top_scorers(url, headers, params)
# Out:
# {'get': 'players/topscorers',
#  'parameters': {'league': '140', 'season': '2024'},
#  'errors': [],
#  'results': 20,
#  'paging': {'current': 1, 'total': 1},
#  'response': [{'player': {'id': 521,
#     'name': 'R. Lewandowski',
#     'firstname': 'Robert',
#     'lastname': 'Lewandowski',
#     'age': 37,
#     'birth': {'date': '1988-08-21', 'place': 'Warszawa', 'country': 'Poland'},
#     'nationality': 'Poland',
#     'height': '185 cm',
#     'weight': '81 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/521.png'},
#    'statistics': [{'team': {'id': 529,
#       'name': 'Barcelona',
#       'logo': 'https://media.api-sports.io/football/teams/529.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 25,
#       'lineups': 24,
#       'minutes': 2016,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.348000',
#       'captain': False},
#      'substitutes': {'in': 1, 'out': 12, 'bench': 2},
#      'shots': {'total': 67, 'on': 38},
#      'goals': {'total': 21, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 404, 'key': 18, 'accuracy': None},
#      'tackles': {'total': 7, 'blocks': 2, 'interceptions': 3},
#      'duels': {'total': 177, 'won': 76},
#      'dribbles': {'attempts': 24, 'success': 15, 'past': None},
#      'fouls': {'drawn': 29, 'committed': 22},
#      'cards': {'yellow': 1, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 3,
#       'missed': 1,
#       'saved': None}}]},
#   {'player': {'id': 278,
#     'name': 'Kylian Mbappé',
#     'firstname': 'Kylian',
#     'lastname': 'Mbappé Lottin',
#     'age': 27,
#     'birth': {'date': '1998-12-20', 'place': 'Paris', 'country': 'France'},
#     'nationality': 'France',
#     'height': '178 cm',
#     'weight': '75 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/278.png'},
#    'statistics': [{'team': {'id': 541,
#       'name': 'Real Madrid',
#       'logo': 'https://media.api-sports.io/football/teams/541.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 25,
#       'lineups': 25,
#       'minutes': 2159,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.572000',
#       'captain': False},
#      'substitutes': {'in': 0, 'out': 11, 'bench': 0},
#      'shots': {'total': 83, 'on': 60},
#      'goals': {'total': 18, 'conceded': 0, 'assists': 3, 'saves': None},
#      'passes': {'total': 794, 'key': 37, 'accuracy': None},
#      'tackles': {'total': 9, 'blocks': None, 'interceptions': None},
#      'duels': {'total': 227, 'won': 99},
#      'dribbles': {'attempts': 134, 'success': 63, 'past': None},
#      'fouls': {'drawn': 25, 'committed': 19},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 5,
#       'missed': 1,
#       'saved': None}}]},
#   {'player': {'id': 46746,
#     'name': 'A. Budimir',
#     'firstname': 'Ante',
#     'lastname': 'Budimir',
#     'age': 34,
#     'birth': {'date': '1991-07-22',
#      'place': 'Zenica',
#      'country': 'Bosnia and Herzegovina'},
#     'nationality': 'Croatia',
#     'height': '190 cm',
#     'weight': '75 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/46746.png'},
#    'statistics': [{'team': {'id': 727,
#       'name': 'Osasuna',
#       'logo': 'https://media.api-sports.io/football/teams/727.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 26,
#       'lineups': 23,
#       'minutes': 1995,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.219230',
#       'captain': False},
#      'substitutes': {'in': 3, 'out': 12, 'bench': 3},
#      'shots': {'total': 50, 'on': 23},
#      'goals': {'total': 14, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 292, 'key': 11, 'accuracy': None},
#      'tackles': {'total': 15, 'blocks': 4, 'interceptions': 1},
#      'duels': {'total': 328, 'won': 150},
#      'dribbles': {'attempts': 27, 'success': 10, 'past': None},
#      'fouls': {'drawn': 21, 'committed': 29},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 6,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 1496,
#     'name': 'Raphinha',
#     'firstname': 'Raphael',
#     'lastname': 'Dias Belloli',
#     'age': 29,
#     'birth': {'date': '1996-12-14',
#      'place': 'Porto Alegre',
#      'country': 'Brazil'},
#     'nationality': 'Brazil',
#     'height': '176 cm',
#     'weight': '68 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/1496.png'},
#    'statistics': [{'team': {'id': 529,
#       'name': 'Barcelona',
#       'logo': 'https://media.api-sports.io/football/teams/529.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 26,
#       'lineups': 25,
#       'minutes': 2135,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.850000',
#       'captain': False},
#      'substitutes': {'in': 1, 'out': 8, 'bench': 1},
#      'shots': {'total': 60, 'on': 34},
#      'goals': {'total': 13, 'conceded': 0, 'assists': 7, 'saves': None},
#      'passes': {'total': 920, 'key': 74, 'accuracy': None},
#      'tackles': {'total': 28, 'blocks': 2, 'interceptions': 5},
#      'duels': {'total': 189, 'won': 104},
#      'dribbles': {'attempts': 79, 'success': 43, 'past': None},
#      'fouls': {'drawn': 27, 'committed': 7},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 128398,
#     'name': 'Oihan Sancet',
#     'firstname': 'Oihan',
#     'lastname': 'Sancet Tirapu',
#     'age': 25,
#     'birth': {'date': '2000-04-25', 'place': 'Pamplona', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '188 cm',
#     'weight': '73 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/128398.png'},
#    'statistics': [{'team': {'id': 531,
#       'name': 'Athletic Club',
#       'logo': 'https://media.api-sports.io/football/teams/531.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 21,
#       'lineups': 17,
#       'minutes': 1357,
#       'number': None,
#       'position': 'Midfielder',
#       'rating': '7.142857',
#       'captain': False},
#      'substitutes': {'in': 4, 'out': 13, 'bench': 4},
#      'shots': {'total': 33, 'on': 17},
#      'goals': {'total': 13, 'conceded': 0, 'assists': 1, 'saves': None},
#      'passes': {'total': 455, 'key': 17, 'accuracy': None},
#      'tackles': {'total': 10, 'blocks': None, 'interceptions': 5},
#      'duels': {'total': 139, 'won': 56},
#      'dribbles': {'attempts': 38, 'success': 19, 'past': None},
#      'fouls': {'drawn': 18, 'committed': 12},
#      'cards': {'yellow': 2, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 2,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 18906,
#     'name': 'Ayoze Pérez',
#     'firstname': 'Ayoze',
#     'lastname': 'Pérez Gutiérrez',
#     'age': 32,
#     'birth': {'date': '1993-07-29',
#      'place': 'Santa Cruz de Tenerife',
#      'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '178 cm',
#     'weight': '66 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/18906.png'},
#    'statistics': [{'team': {'id': 533,
#       'name': 'Villarreal',
#       'logo': 'https://media.api-sports.io/football/teams/533.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 19,
#       'lineups': 12,
#       'minutes': 1168,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.100000',
#       'captain': False},
#      'substitutes': {'in': 7, 'out': 7, 'bench': 7},
#      'shots': {'total': 35, 'on': 16},
#      'goals': {'total': 11, 'conceded': 0, 'assists': 0, 'saves': None},
#      'passes': {'total': 216, 'key': 20, 'accuracy': None},
#      'tackles': {'total': 18, 'blocks': None, 'interceptions': 4},
#      'duels': {'total': 152, 'won': 75},
#      'dribbles': {'attempts': 38, 'success': 20, 'past': None},
#      'fouls': {'drawn': 29, 'committed': 14},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 0,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 25458,
#     'name': 'D. Lukebakio',
#     'firstname': 'Dodi',
#     'lastname': 'Lukebakio Ngandoli',
#     'age': 28,
#     'birth': {'date': '1997-09-24', 'place': 'Asse', 'country': 'Belgium'},
#     'nationality': 'Belgium',
#     'height': '187 cm',
#     'weight': '77 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/25458.png'},
#    'statistics': [{'team': {'id': 536,
#       'name': 'Sevilla',
#       'logo': 'https://media.api-sports.io/football/teams/536.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 27,
#       'lineups': 26,
#       'minutes': 2261,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.196296',
#       'captain': False},
#      'substitutes': {'in': 1, 'out': 11, 'bench': 1},
#      'shots': {'total': 55, 'on': 31},
#      'goals': {'total': 11, 'conceded': 0, 'assists': 1, 'saves': None},
#      'passes': {'total': 663, 'key': 38, 'accuracy': None},
#      'tackles': {'total': 18, 'blocks': None, 'interceptions': 4},
#      'duels': {'total': 292, 'won': 142},
#      'dribbles': {'attempts': 133, 'success': 71, 'past': None},
#      'fouls': {'drawn': 40, 'committed': 26},
#      'cards': {'yellow': 2, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 47396,
#     'name': 'Kike García',
#     'firstname': 'Enrique',
#     'lastname': 'García Martínez',
#     'age': 36,
#     'birth': {'date': '1989-11-25',
#      'place': 'Motilla del Palancar',
#      'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '186 cm',
#     'weight': '79 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/47396.png'},
#    'statistics': [{'team': {'id': 542,
#       'name': 'Alaves',
#       'logo': 'https://media.api-sports.io/football/teams/542.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 26,
#       'lineups': 20,
#       'minutes': 1782,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.038461',
#       'captain': False},
#      'substitutes': {'in': 6, 'out': 14, 'bench': 6},
#      'shots': {'total': 31, 'on': 18},
#      'goals': {'total': 11, 'conceded': 0, 'assists': 0, 'saves': None},
#      'passes': {'total': 396, 'key': 12, 'accuracy': None},
#      'tackles': {'total': 9, 'blocks': 2, 'interceptions': None},
#      'duels': {'total': 276, 'won': 141},
#      'dribbles': {'attempts': 21, 'success': 10, 'past': None},
#      'fouls': {'drawn': 41, 'committed': 39},
#      'cards': {'yellow': 4, 'yellowred': 1, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 2,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 6009,
#     'name': 'J. Álvarez',
#     'firstname': 'Julián',
#     'lastname': 'Álvarez',
#     'age': 25,
#     'birth': {'date': '2000-01-31', 'place': 'Cachín', 'country': 'Argentina'},
#     'nationality': 'Argentina',
#     'height': '170 cm',
#     'weight': '71 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/6009.png'},
#    'statistics': [{'team': {'id': 530,
#       'name': 'Atletico Madrid',
#       'logo': 'https://media.api-sports.io/football/teams/530.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 27,
#       'lineups': 21,
#       'minutes': 1766,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.077777',
#       'captain': False},
#      'substitutes': {'in': 6, 'out': 14, 'bench': 6},
#      'shots': {'total': 41, 'on': 25},
#      'goals': {'total': 10, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 612, 'key': 25, 'accuracy': None},
#      'tackles': {'total': 19, 'blocks': None, 'interceptions': None},
#      'duels': {'total': 167, 'won': 56},
#      'dribbles': {'attempts': 40, 'success': 23, 'past': None},
#      'fouls': {'drawn': 3, 'committed': 22},
#      'cards': {'yellow': 4, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 8492,
#     'name': 'A. Sørloth',
#     'firstname': 'Alexander',
#     'lastname': 'Sørloth',
#     'age': 30,
#     'birth': {'date': '1995-12-05', 'place': 'Trondheim', 'country': 'Norway'},
#     'nationality': 'Norway',
#     'height': '195 cm',
#     'weight': '90 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/8492.png'},
#    'statistics': [{'team': {'id': 530,
#       'name': 'Atletico Madrid',
#       'logo': 'https://media.api-sports.io/football/teams/530.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 24,
#       'lineups': 9,
#       'minutes': 994,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '6.945833',
#       'captain': False},
#      'substitutes': {'in': 15, 'out': 7, 'bench': 17},
#      'shots': {'total': 32, 'on': 21},
#      'goals': {'total': 10, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 249, 'key': 9, 'accuracy': None},
#      'tackles': {'total': 5, 'blocks': 1, 'interceptions': 1},
#      'duels': {'total': 184, 'won': 103},
#      'dribbles': {'attempts': 24, 'success': 13, 'past': None},
#      'fouls': {'drawn': 12, 'committed': 18},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 762,
#     'name': 'Vinícius Júnior',
#     'firstname': 'Vinícius José',
#     'lastname': 'Paixão de Oliveira Júnior',
#     'age': 25,
#     'birth': {'date': '2000-07-12',
#      'place': 'São Gonçalo',
#      'country': 'Brazil'},
#     'nationality': 'Brazil',
#     'height': '176 cm',
#     'weight': '73 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/762.png'},
#    'statistics': [{'team': {'id': 541,
#       'name': 'Real Madrid',
#       'logo': 'https://media.api-sports.io/football/teams/541.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 21,
#       'lineups': 19,
#       'minutes': 1721,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.423809',
#       'captain': False},
#      'substitutes': {'in': 2, 'out': 8, 'bench': 2},
#      'shots': {'total': 47, 'on': 21},
#      'goals': {'total': 10, 'conceded': 0, 'assists': 5, 'saves': None},
#      'passes': {'total': 596, 'key': 42, 'accuracy': None},
#      'tackles': {'total': 17, 'blocks': None, 'interceptions': 2},
#      'duels': {'total': 285, 'won': 133},
#      'dribbles': {'attempts': 134, 'success': 62, 'past': None},
#      'fouls': {'drawn': 53, 'committed': 25},
#      'cards': {'yellow': 7, 'yellowred': 0, 'red': 1},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 2,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 47324,
#     'name': 'Sandro Ramírez',
#     'firstname': 'Sandro',
#     'lastname': 'Ramírez Castillo',
#     'age': 30,
#     'birth': {'date': '1995-07-09',
#      'place': 'Las Palmas de Gran Canaria',
#      'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '175 cm',
#     'weight': '71 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/47324.png'},
#    'statistics': [{'team': {'id': 534,
#       'name': 'Las Palmas',
#       'logo': 'https://media.api-sports.io/football/teams/534.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 22,
#       'lineups': 19,
#       'minutes': 1562,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.036363',
#       'captain': False},
#      'substitutes': {'in': 3, 'out': 14, 'bench': 3},
#      'shots': {'total': 29, 'on': 18},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 3, 'saves': None},
#      'passes': {'total': 395, 'key': 19, 'accuracy': None},
#      'tackles': {'total': 22, 'blocks': None, 'interceptions': 14},
#      'duels': {'total': 158, 'won': 73},
#      'dribbles': {'attempts': 31, 'success': 12, 'past': None},
#      'fouls': {'drawn': 30, 'committed': 21},
#      'cards': {'yellow': 5, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 0,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 56,
#     'name': 'A. Griezmann',
#     'firstname': 'Antoine',
#     'lastname': 'Griezmann',
#     'age': 34,
#     'birth': {'date': '1991-03-21', 'place': 'Mâcon', 'country': 'France'},
#     'nationality': 'France',
#     'height': '176 cm',
#     'weight': '73 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/56.png'},
#    'statistics': [{'team': {'id': 530,
#       'name': 'Atletico Madrid',
#       'logo': 'https://media.api-sports.io/football/teams/530.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 27,
#       'lineups': 23,
#       'minutes': 1944,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.300000',
#       'captain': False},
#      'substitutes': {'in': 4, 'out': 15, 'bench': 4},
#      'shots': {'total': 29, 'on': 14},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 5, 'saves': None},
#      'passes': {'total': 997, 'key': 39, 'accuracy': None},
#      'tackles': {'total': 26, 'blocks': None, 'interceptions': 6},
#      'duels': {'total': 145, 'won': 72},
#      'dribbles': {'attempts': 21, 'success': 10, 'past': None},
#      'fouls': {'drawn': 22, 'committed': 10},
#      'cards': {'yellow': 2, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 1,
#       'saved': None}}]},
#   {'player': {'id': 343684,
#     'name': 'T. Barry',
#     'firstname': 'Thierno',
#     'lastname': 'Barry',
#     'age': 23,
#     'birth': {'date': '2002-10-21', 'place': 'Lyon', 'country': 'France'},
#     'nationality': 'France',
#     'height': '195 cm',
#     'weight': '82 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/343684.png'},
#    'statistics': [{'team': {'id': 533,
#       'name': 'Villarreal',
#       'logo': 'https://media.api-sports.io/football/teams/533.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 25,
#       'lineups': 17,
#       'minutes': 1574,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '6.940000',
#       'captain': False},
#      'substitutes': {'in': 8, 'out': 7, 'bench': 8},
#      'shots': {'total': 47, 'on': 17},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 3, 'saves': None},
#      'passes': {'total': 225, 'key': 17, 'accuracy': None},
#      'tackles': {'total': 11, 'blocks': 2, 'interceptions': None},
#      'duels': {'total': 230, 'won': 125},
#      'dribbles': {'attempts': 26, 'success': 10, 'past': None},
#      'fouls': {'drawn': 34, 'committed': 30},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 47349,
#     'name': 'Javi Puado',
#     'firstname': 'Javier',
#     'lastname': 'Puado Díaz',
#     'age': 27,
#     'birth': {'date': '1998-05-25', 'place': 'Barcelona', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '177 cm',
#     'weight': '69 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/47349.png'},
#    'statistics': [{'team': {'id': 540,
#       'name': 'Espanyol',
#       'logo': 'https://media.api-sports.io/football/teams/540.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 24,
#       'lineups': 24,
#       'minutes': 2057,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '6.895833',
#       'captain': False},
#      'substitutes': {'in': 0, 'out': 8, 'bench': 0},
#      'shots': {'total': 38, 'on': 14},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 1, 'saves': None},
#      'passes': {'total': 427, 'key': 15, 'accuracy': None},
#      'tackles': {'total': 15, 'blocks': 2, 'interceptions': 4},
#      'duels': {'total': 144, 'won': 58},
#      'dribbles': {'attempts': 41, 'success': 16, 'past': None},
#      'fouls': {'drawn': 20, 'committed': 14},
#      'cards': {'yellow': 4, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 2,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 47258,
#     'name': 'M. Arambarri',
#     'firstname': 'Mauro Wilney',
#     'lastname': 'Arambarri Rosa',
#     'age': 30,
#     'birth': {'date': '1995-09-30', 'place': 'Tropezón', 'country': 'Uruguay'},
#     'nationality': 'Uruguay',
#     'height': '175 cm',
#     'weight': '71 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/47258.png'},
#    'statistics': [{'team': {'id': 546,
#       'name': 'Getafe',
#       'logo': 'https://media.api-sports.io/football/teams/546.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 25,
#       'lineups': 21,
#       'minutes': 1809,
#       'number': None,
#       'position': 'Midfielder',
#       'rating': '6.908000',
#       'captain': False},
#      'substitutes': {'in': 4, 'out': 6, 'bench': 4},
#      'shots': {'total': 27, 'on': 13},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 0, 'saves': None},
#      'passes': {'total': 533, 'key': 9, 'accuracy': None},
#      'tackles': {'total': 30, 'blocks': 5, 'interceptions': 8},
#      'duels': {'total': 233, 'won': 116},
#      'dribbles': {'attempts': 22, 'success': 13, 'past': None},
#      'fouls': {'drawn': 32, 'committed': 28},
#      'cards': {'yellow': 8, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 3,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 47445,
#     'name': 'Iago Aspas',
#     'firstname': 'Iago',
#     'lastname': 'Aspas Juncal',
#     'age': 38,
#     'birth': {'date': '1987-08-01', 'place': 'Moaña', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '176 cm',
#     'weight': '67 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/47445.png'},
#    'statistics': [{'team': {'id': 538,
#       'name': 'Celta Vigo',
#       'logo': 'https://media.api-sports.io/football/teams/538.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 20,
#       'lineups': 14,
#       'minutes': 1326,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.320000',
#       'captain': False},
#      'substitutes': {'in': 6, 'out': 5, 'bench': 8},
#      'shots': {'total': 34, 'on': 19},
#      'goals': {'total': 8, 'conceded': 0, 'assists': 3, 'saves': None},
#      'passes': {'total': 634, 'key': 25, 'accuracy': None},
#      'tackles': {'total': 12, 'blocks': 1, 'interceptions': 6},
#      'duels': {'total': 111, 'won': 59},
#      'dribbles': {'attempts': 17, 'success': 10, 'past': None},
#      'fouls': {'drawn': 30, 'committed': 14},
#      'cards': {'yellow': 3, 'yellowred': 1, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 4,
#       'missed': 1,
#       'saved': None}}]},
#   {'player': {'id': 47264,
#     'name': 'Hugo Duro',
#     'firstname': 'Hugo',
#     'lastname': 'Duro Perales',
#     'age': 26,
#     'birth': {'date': '1999-11-10', 'place': 'Getafe', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '177 cm',
#     'weight': '70 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/47264.png'},
#    'statistics': [{'team': {'id': 532,
#       'name': 'Valencia',
#       'logo': 'https://media.api-sports.io/football/teams/532.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 22,
#       'lineups': 20,
#       'minutes': 1702,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '6.872727',
#       'captain': False},
#      'substitutes': {'in': 2, 'out': 8, 'bench': 3},
#      'shots': {'total': 28, 'on': 12},
#      'goals': {'total': 7, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 329, 'key': 12, 'accuracy': None},
#      'tackles': {'total': 12, 'blocks': 2, 'interceptions': 9},
#      'duels': {'total': 262, 'won': 109},
#      'dribbles': {'attempts': 19, 'success': 7, 'past': None},
#      'fouls': {'drawn': 41, 'committed': 28},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 0,
#       'missed': 0,
#       'saved': None}}]},
#   {'player': {'id': 129718,
#     'name': 'J. Bellingham',
#     'firstname': 'Jude Victor William',
#     'lastname': 'Bellingham',
#     'age': 22,
#     'birth': {'date': '2003-06-29',
#      'place': 'Stourbridge',
#      'country': 'England'},
#     'nationality': 'England',
#     'height': '186 cm',
#     'weight': '75 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/129718.png'},
#    'statistics': [{'team': {'id': 541,
#       'name': 'Real Madrid',
#       'logo': 'https://media.api-sports.io/football/teams/541.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 21,
#       'lineups': 21,
#       'minutes': 1721,
#       'number': None,
#       'position': 'Midfielder',
#       'rating': '7.576190',
#       'captain': False},
#      'substitutes': {'in': 0, 'out': 9, 'bench': 0},
#      'shots': {'total': 30, 'on': 15},
#      'goals': {'total': 7, 'conceded': 0, 'assists': 6, 'saves': None},
#      'passes': {'total': 1070, 'key': 26, 'accuracy': 44},
#      'tackles': {'total': 44, 'blocks': 2, 'interceptions': 18},
#      'duels': {'total': 224, 'won': 134},
#      'dribbles': {'attempts': 43, 'success': 26, 'past': None},
#      'fouls': {'drawn': 47, 'committed': 23},
#      'cards': {'yellow': 3, 'yellowred': 0, 'red': 1},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 1,
#       'saved': None}}]},
#   {'player': {'id': 129791,
#     'name': 'Fábio Silva',
#     'firstname': 'Fábio Daniel',
#     'lastname': 'Soares Silva',
#     'age': 23,
#     'birth': {'date': '2002-07-19', 'place': 'Porto', 'country': 'Portugal'},
#     'nationality': 'Portugal',
#     'height': '185 cm',
#     'weight': '75 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/129791.png'},
#    'statistics': [{'team': {'id': 534,
#       'name': 'Las Palmas',
#       'logo': 'https://media.api-sports.io/football/teams/534.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media.api-sports.io/flags/es.svg',
#       'season': 2024},
#      'games': {'appearences': 19,
#       'lineups': 17,
#       'minutes': 1436,
#       'number': None,
#       'position': 'Attacker',
#       'rating': '7.010526',
#       'captain': False},
#      'substitutes': {'in': 2, 'out': 11, 'bench': 2},
#      'shots': {'total': 37, 'on': 19},
#      'goals': {'total': 7, 'conceded': 0, 'assists': 2, 'saves': None},
#      'passes': {'total': 323, 'key': 10, 'accuracy': None},
#      'tackles': {'total': 10, 'blocks': None, 'interceptions': 3},
#      'duels': {'total': 214, 'won': 99},
#      'dribbles': {'attempts': 36, 'success': 15, 'past': None},
#      'fouls': {'drawn': 34, 'committed': 31},
#      'cards': {'yellow': 7, 'yellowred': 0, 'red': 0},
#      'penalty': {'won': None,
#       'commited': None,
#       'scored': 1,
#       'missed': 1,
#       'saved': None}}]}]}

# %%
#This step represents the transformation phase of the ETL pipeline (T).
def process_top_scorers(data):
    """
    Parse the JSON data required for the top scorers 
    """
    top_scorers = []
    for scorer_data in data['response']:#The data we need is found in the response key. Response is an array of objects with all the detailed information we need about each top goal scorer.
        statistics = scorer_data['statistics'][0]

        # Set up constants for processing data 
        player = scorer_data['player']
        player_name = player['name']
        club_name = statistics['team']['name']
        club_logo = statistics['team']['logo']
        total_goals = int(statistics['goals']['total'])
        penalty_goals = int(statistics['penalty']['scored'])
        total_shots = int(statistics['shots']['total'])
        assists = int(statistics['goals']['assists']) if statistics['goals']['assists'] else 0
        matches_played = int(statistics['games']['appearences'])
        minutes_played = int(statistics['games']['minutes'])
        dob = datetime.strptime(player['birth']['date'], '%Y-%m-%d')
        age = (datetime.now() - dob).days // 365

        # Append data 
        top_scorers.append({
            'player': player_name,
            'club': club_name,
            'total_goals': total_goals,
            'penalty_goals': penalty_goals,
            'assists': assists,
            'matches': matches_played,
            'mins': minutes_played,
            'age': age,
            'total_shots': total_shots,
            'club_logo':club_logo
        })
    return top_scorers
process_top_scorers(get_top_scorers(url, headers, params))
# Out:
# [{'player': 'R. Lewandowski',
#   'club': 'Barcelona',
#   'total_goals': 21,
#   'penalty_goals': 3,
#   'assists': 2,
#   'matches': 25,
#   'mins': 2016,
#   'age': 36,
#   'total_shots': 67,
#   'club_logo': 'https://media.api-sports.io/football/teams/529.png'},
#  {'player': 'Kylian Mbappé',
#   'club': 'Real Madrid',
#   'total_goals': 18,
#   'penalty_goals': 5,
#   'assists': 3,
#   'matches': 25,
#   'mins': 2159,
#   'age': 26,
#   'total_shots': 83,
#   'club_logo': 'https://media.api-sports.io/football/teams/541.png'},
#  {'player': 'A. Budimir',
#   'club': 'Osasuna',
#   'total_goals': 14,
#   'penalty_goals': 6,
#   'assists': 2,
#   'matches': 26,
#   'mins': 1995,
#   'age': 33,
#   'total_shots': 50,
#   'club_logo': 'https://media.api-sports.io/football/teams/727.png'},
#  {'player': 'Raphinha',
#   'club': 'Barcelona',
#   'total_goals': 13,
#   'penalty_goals': 1,
#   'assists': 7,
#   'matches': 26,
#   'mins': 2135,
#   'age': 28,
#   'total_shots': 60,
#   'club_logo': 'https://media.api-sports.io/football/teams/529.png'},
#  {'player': 'Oihan Sancet',
#   'club': 'Athletic Club',
#   'total_goals': 13,
#   'penalty_goals': 2,
#   'assists': 1,
#   'matches': 21,
#   'mins': 1357,
#   'age': 24,
#   'total_shots': 33,
#   'club_logo': 'https://media.api-sports.io/football/teams/531.png'},
#  {'player': 'Ayoze Pérez',
#   'club': 'Villarreal',
#   'total_goals': 11,
#   'penalty_goals': 0,
#   'assists': 0,
#   'matches': 19,
#   'mins': 1168,
#   'age': 31,
#   'total_shots': 35,
#   'club_logo': 'https://media.api-sports.io/football/teams/533.png'},
#  {'player': 'D. Lukebakio',
#   'club': 'Sevilla',
#   'total_goals': 11,
#   'penalty_goals': 1,
#   'assists': 1,
#   'matches': 27,
#   'mins': 2261,
#   'age': 27,
#   'total_shots': 55,
#   'club_logo': 'https://media.api-sports.io/football/teams/536.png'},
#  {'player': 'Kike García',
#   'club': 'Alaves',
#   'total_goals': 11,
#   'penalty_goals': 2,
#   'assists': 0,
#   'matches': 26,
#   'mins': 1782,
#   'age': 35,
#   'total_shots': 31,
#   'club_logo': 'https://media.api-sports.io/football/teams/542.png'},
#  {'player': 'J. Álvarez',
#   'club': 'Atletico Madrid',
#   'total_goals': 10,
#   'penalty_goals': 1,
#   'assists': 2,
#   'matches': 27,
#   'mins': 1766,
#   'age': 25,
#   'total_shots': 41,
#   'club_logo': 'https://media.api-sports.io/football/teams/530.png'},
#  {'player': 'A. Sørloth',
#   'club': 'Atletico Madrid',
#   'total_goals': 10,
#   'penalty_goals': 1,
#   'assists': 2,
#   'matches': 24,
#   'mins': 994,
#   'age': 29,
#   'total_shots': 32,
#   'club_logo': 'https://media.api-sports.io/football/teams/530.png'},
#  {'player': 'Vinícius Júnior',
#   'club': 'Real Madrid',
#   'total_goals': 10,
#   'penalty_goals': 2,
#   'assists': 5,
#   'matches': 21,
#   'mins': 1721,
#   'age': 24,
#   'total_shots': 47,
#   'club_logo': 'https://media.api-sports.io/football/teams/541.png'},
#  {'player': 'Sandro Ramírez',
#   'club': 'Las Palmas',
#   'total_goals': 8,
#   'penalty_goals': 0,
#   'assists': 3,
#   'matches': 22,
#   'mins': 1562,
#   'age': 29,
#   'total_shots': 29,
#   'club_logo': 'https://media.api-sports.io/football/teams/534.png'},
#  {'player': 'A. Griezmann',
#   'club': 'Atletico Madrid',
#   'total_goals': 8,
#   'penalty_goals': 1,
#   'assists': 5,
#   'matches': 27,
#   'mins': 1944,
#   'age': 34,
#   'total_shots': 29,
#   'club_logo': 'https://media.api-sports.io/football/teams/530.png'},
#  {'player': 'T. Barry',
#   'club': 'Villarreal',
#   'total_goals': 8,
#   'penalty_goals': 1,
#   'assists': 3,
#   'matches': 25,
#   'mins': 1574,
#   'age': 22,
#   'total_shots': 47,
#   'club_logo': 'https://media.api-sports.io/football/teams/533.png'},
#  {'player': 'Javi Puado',
#   'club': 'Espanyol',
#   'total_goals': 8,
#   'penalty_goals': 2,
#   'assists': 1,
#   'matches': 24,
#   'mins': 2057,
#   'age': 26,
#   'total_shots': 38,
#   'club_logo': 'https://media.api-sports.io/football/teams/540.png'},
#  {'player': 'M. Arambarri',
#   'club': 'Getafe',
#   'total_goals': 8,
#   'penalty_goals': 3,
#   'assists': 0,
#   'matches': 25,
#   'mins': 1809,
#   'age': 29,
#   'total_shots': 27,
#   'club_logo': 'https://media.api-sports.io/football/teams/546.png'},
#  {'player': 'Iago Aspas',
#   'club': 'Celta Vigo',
#   'total_goals': 8,
#   'penalty_goals': 4,
#   'assists': 3,
#   'matches': 20,
#   'mins': 1326,
#   'age': 37,
#   'total_shots': 34,
#   'club_logo': 'https://media.api-sports.io/football/teams/538.png'},
#  {'player': 'Hugo Duro',
#   'club': 'Valencia',
#   'total_goals': 7,
#   'penalty_goals': 0,
#   'assists': 2,
#   'matches': 22,
#   'mins': 1702,
#   'age': 25,
#   'total_shots': 28,
#   'club_logo': 'https://media.api-sports.io/football/teams/532.png'},
#  {'player': 'J. Bellingham',
#   'club': 'Real Madrid',
#   'total_goals': 7,
#   'penalty_goals': 1,
#   'assists': 6,
#   'matches': 21,
#   'mins': 1721,
#   'age': 21,
#   'total_shots': 30,
#   'club_logo': 'https://media.api-sports.io/football/teams/541.png'},
#  {'player': 'Fábio Silva',
#   'club': 'Las Palmas',
#   'total_goals': 7,
#   'penalty_goals': 1,
#   'assists': 2,
#   'matches': 19,
#   'mins': 1436,
#   'age': 22,
#   'total_shots': 37,
#   'club_logo': 'https://media.api-sports.io/football/teams/534.png'}]

# %%
def create_dataframe(top_scorers):
    """
    Convert list of dictionaries into a Pandas dataframe and process it
    """

    df = pd.DataFrame(top_scorers)

    # Sort dataframe first by 'total_goals' in descending order, then by 'assists' in descending order
    df.sort_values(by=['total_goals', 'assists'], ascending=[False, False], inplace=True)

    # Reset index after sorting to reflect new order
    df.reset_index(drop=True, inplace=True)

    # Recalculate ranks based on the sorted order of 'total_goals' using dense method 
    df['position'] = df['total_goals'].rank(method='dense', ascending=False).astype(int)

    # Specify the columns to include in the final dataframe in the desired order
    df = df[['position', 'player', 'club', 'total_goals', 'penalty_goals', 'assists', 'matches', 'mins', 'age','total_shots','club_logo']]

    return df
create_dataframe(process_top_scorers(get_top_scorers(url, headers, params)))
# Out:
#     position           player             club  total_goals  penalty_goals  \
# 0          1   R. Lewandowski        Barcelona           21              3
# 1          2    Kylian Mbappé      Real Madrid           18              5
# 2          3       A. Budimir          Osasuna           14              6
# 3          4         Raphinha        Barcelona           13              1
# 4          4     Oihan Sancet    Athletic Club           13              2
# 5          5     D. Lukebakio          Sevilla           11              1
# 6          5      Ayoze Pérez       Villarreal           11              0
# 7          5      Kike García           Alaves           11              2
# 8          6  Vinícius Júnior      Real Madrid           10              2
# 9          6       J. Álvarez  Atletico Madrid           10              1
# 10         6       A. Sørloth  Atletico Madrid           10              1
# 11         7     A. Griezmann  Atletico Madrid            8              1
# 12         7   Sandro Ramírez       Las Palmas            8              0
# 13         7         T. Barry       Villarreal            8              1
# 14         7       Iago Aspas       Celta Vigo            8              4
# 15         7       Javi Puado         Espanyol            8              2
# 16         7     M. Arambarri           Getafe            8              3
# 17         8    J. Bellingham      Real Madrid            7              1
# 18         8        Hugo Duro         Valencia            7              0
# 19         8      Fábio Silva       Las Palmas            7              1
#
#     assists  matches  mins  age  total_shots  \
# 0         2       25  2016   36           67
# 1         3       25  2159   26           83
# 2         2       26  1995   33           50
# 3         7       26  2135   28           60
# 4         1       21  1357   24           33
# 5         1       27  2261   27           55
# 6         0       19  1168   31           35
# 7         0       26  1782   35           31
# 8         5       21  1721   24           47
# 9         2       27  1766   25           41
# 10        2       24   994   29           32
# 11        5       27  1944   34           29
# 12        3       22  1562   29           29
# 13        3       25  1574   22           47
# 14        3       20  1326   37           34
# 15        1       24  2057   26           38
# 16        0       25  1809   29           27
# 17        6       21  1721   21           30
# 18        2       22  1702   25           28
# 19        2       19  1436   22           37
#
#                                             club_logo
# 0   https://media.api-sports.io/football/teams/529...
# 1   https://media.api-sports.io/football/teams/541...
# 2   https://media.api-sports.io/football/teams/727...
# 3   https://media.api-sports.io/football/teams/529...
# 4   https://media.api-sports.io/football/teams/531...
# 5   https://media.api-sports.io/football/teams/536...
# 6   https://media.api-sports.io/football/teams/533...
# 7   https://media.api-sports.io/football/teams/542...
# 8   https://media.api-sports.io/football/teams/541...
# 9   https://media.api-sports.io/football/teams/530...
# 10  https://media.api-sports.io/football/teams/530...
# 11  https://media.api-sports.io/football/teams/530...
# 12  https://media.api-sports.io/football/teams/534...
# 13  https://media.api-sports.io/football/teams/533...
# 14  https://media.api-sports.io/football/teams/538...
# 15  https://media.api-sports.io/football/teams/540...
# 16  https://media.api-sports.io/football/teams/546...
# 17  https://media.api-sports.io/football/teams/541...
# 18  https://media.api-sports.io/football/teams/532...
# 19  https://media.api-sports.io/football/teams/534...

# %%
load_dotenv('keys.env')
# Load MySQL database credentials
SERVER = os.getenv('SERVER')
MY_DATABASE = os.getenv('MY_DATABASE')

# %%
def create_db_connection(server_name, db_name):
    """
    Establish a connection to the SQL Server database using Windows Authentication.
    """
    db_connection = None
    try:
        db_connection = pyodbc.connect(
            f'DRIVER={{SQL Server}};'
            f'SERVER={server_name};'
            f'DATABASE={db_name};'
            f'Trusted_Connection=yes;'
        )
        print("✅ SQL Server Database connection successful!")

    except pyodbc.Error as e:
        print(f"❌ [DATABASE CONNECTION ERROR]: {e}")

    return db_connection

create_db_connection(SERVER, MY_DATABASE)
# Out:
# ✅ SQL Server Database connection successful!

# %%
def create_table(db_connection):
    """
    Create a table if it does not exist in the SQL Server database
    """
    CREATE_TABLE_SQL_QUERY = """
    IF NOT EXISTS (SELECT * FROM sysobjects WHERE name='top_scorers' AND xtype='U')
    CREATE TABLE top_scorers (
        position INT,
        player VARCHAR(255),
        club VARCHAR(255),
        total_goals INT,
        penalty_goals INT,
        assists INT,
        matches INT,
        mins INT,
        age INT,
        total_shots INT, 
        club_logo VARCHAR(255),
        PRIMARY KEY (player, club)
    );
    """
    
    try:
        cursor = db_connection.cursor()
        cursor.execute(CREATE_TABLE_SQL_QUERY)
        db_connection.commit()
        print("✅ Table 'top_scorers' created successfully!")

    except pyodbc.Error as e:
        print(f"❌ [CREATING TABLE ERROR]: {e}")
create_table(create_db_connection(SERVER, MY_DATABASE))
# Out:
# ✅ SQL Server Database connection successful!
# ✅ Table 'top_scorers' created successfully!

# %%
# Insert data into the table
def insert_into_table(db_connection, df):
    """
    Insert or update the top scorers data in the database from the dataframe
    """
    cursor = db_connection.cursor()

    INSERT_DATA_SQL_QUERY = """
    MERGE INTO top_scorers AS target
    USING (VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)) AS source (position, player, club, total_goals, penalty_goals, assists, matches, mins, age, total_shots, club_logo)
    ON target.player = source.player AND target.club = source.club
    WHEN MATCHED THEN
        UPDATE SET
            target.total_goals = source.total_goals,
            target.penalty_goals = source.penalty_goals,
            target.assists = source.assists,
            target.matches = source.matches,
            target.mins = source.mins,
            target.age = source.age,
            target.total_shots = source.total_shots,  -- Update this line if the column name is different
            target.club_logo = source.club_logo
    WHEN NOT MATCHED THEN
        INSERT (position, player, club, total_goals, penalty_goals, assists, matches, mins, age, total_shots, club_logo)  -- Update this line if the column name is different
        VALUES (source.position, source.player, source.club, source.total_goals, source.penalty_goals, source.assists, source.matches, source.mins, source.age, source.total_shots, source.club_logo);
    """

    # Create a list of tuples from the dataframe values
    data_values_as_tuples = [tuple(x) for x in df.to_numpy()]

    # Execute the query
    cursor.executemany(INSERT_DATA_SQL_QUERY, data_values_as_tuples)
    db_connection.commit()
    print("Data inserted or updated successfully ✅")
insert_into_table(create_db_connection(SERVER, MY_DATABASE), create_dataframe(process_top_scorers(get_top_scorers(url, headers, params))))
# Out:
# ✅ SQL Server Database connection successful!
# Data inserted or updated successfully ✅

# %%
def run_data_pipeline():
    """
    Execute the ETL pipeline 
    """
    check_rate_limits()

    data = get_top_scorers(url, headers, params)

    if data and 'response' in data and data['response']:
        top_scorers = process_top_scorers(data)
        df = create_dataframe(top_scorers)
        print(df.to_string(index=False)) 

    else:
        print("No data available or an error occurred ❌")

    db_connection = create_db_connection(SERVER, MY_DATABASE)


    # If connection is successful, proceed with creating table and inserting data
    if db_connection is not None:
        create_table(db_connection)  
        df = create_dataframe(top_scorers) 
        insert_into_table(db_connection, df)  

if __name__ == "__main__":
    run_data_pipeline()
# Out:
# {'daily_limit': '100', 'daily_remaining': '75', 'minute_limit': None, 'minute_remaining': None}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 27
#      24         insert_into_table(db_connection, df)
#      26 if __name__ == "__main__":
# ---> 27     run_data_pipeline()
#
# Cell In[5], line 7, in run_data_pipeline()
#       2 """
#       3 Execute the ETL pipeline
#       4 """
#       5 check_rate_limits()
# ----> 7 data = get_top_scorers(url, headers, params)
#       9 if data and 'response' in data and data['response']:
#      10     top_scorers = process_top_scorers(data)
#
# NameError: name 'get_top_scorers' is not defined
